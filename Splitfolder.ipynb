# %%
# !pip install split_folders
# Out:
# Requirement already satisfied: split_folders in c:\users\user\appdata\local\programs\python\python37\lib\site-packages (0.5.1)

# %%
import splitfolders

# %%
input_folder='basedata/Input_dataset'
output='basedata/processed_data'
splitfolders.ratio(input_folder,output,seed=42,ratio=(.6,.2,.2))

# %%
help(splitfolders.ratio)
# Out:
# Help on function ratio in module splitfolders.split:
#
# ratio(input, output='output', seed=1337, ratio=(0.8, 0.1, 0.1), group_prefix=None, move=False)
